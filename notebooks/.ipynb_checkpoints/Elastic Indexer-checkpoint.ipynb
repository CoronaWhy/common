# %%
import pandas as pd
import spacy
import os
import scispacy
from spacy import displacy
from tqdm.notebook import tqdm

# %%
sentences = df[df["sentence"].str.contains("population") | (df["sentence"].str.contains("sample") & df["sentence"].str.contains("size")]["sentence"]
sentences.reset_index(drop=True,inplace=True)
nlp = spacy.load("en_core_sci_lg")
doc = nlp(sentences[0])
displacy.serve(doc, style="dep")

# %%
subject = doc[7]

# %%
subject = doc[7]
a = [i.dep_ for i in subject.lefts]
b = [i for i in subject.lefts]
c = [i for i in doc[2].ancestors]

# %%
vec_df.fillna("[]",inplace=True)
npr = list(set(vec_df[vec_df["sentence"].str.contains("not peer")]["paper_id"].to_list()))

# %%
len(npr)

# %%
import pandas as pd
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import os

# %%
def bulk_index(df, index_name): 
    # This method will process rows of a given dataframe
    # into dicts indexable by ES. Those are then indexed.
    
    es = Elasticsearch()

    helpers.bulk(es, doc_generator(df, index_name))
    
def doc_generator(df, index_name):
    # This function creates documents from dataframe rows, and then 
    # indexes those documents in ElasticSearch
    df_iter = df.iterrows()
    for index, document in df_iter:
        yield {
                "_index": index_name,
                "article": document.to_dict(),
            }
    return True

# %%
directory = "/home/acorn/Documents/covid/v6/v6_text/"
vec_df = pd.concat([pd.read_pickle(directory + f, compression="gzip") for f in os.listdir(directory)])

# %%
v7 = pd.read_json("/home/acorn/Documents/covid/v7/v7_text.json", orient="records")
if "sentenc_id" in v7.columns:
    v7.rename(columns={"sentenc_id": "sentence_id"}, inplace=True)

# %%
df = pd.concat([vec_df, v7])
del v7
del vec_df

# %%
#df = pd.read_pickle("v6-7bySection.pkl", compression="gzip")
#bulk_index(df, index_name="cordv7sections")
del df 
print("Sections done.")
df = pd.read_pickle("v6-7bySentence.pkl",compression="gzip")
bulk_index(df, index_name="cord19sentences")
del df
print("Sentences done")
# Out:
# Sections done.

# %%
#df.fillna("[]", inplace=True)
column_remap = {'lemma':'sum', 
                'UMLS':'sum', 
                'GGP':'sum', 
                'SO':'sum', 
                'TAXON':'sum', 
                'CHEBI':'sum', 
                'GO':'sum', 
                'CL':'sum', 
                'DNA':'sum',
                'CELL_TYPE':'sum', 
                'CELL_LINE':'sum', 
                'RNA':'sum', 
                'PROTEIN':'sum', 
                'DISEASE':'sum', 
                'CHEMICAL':'sum', 
                'CANCER':'sum', 
                'ORGAN':'sum', 
                'TISSUE':'sum', 
                'ORGANISM':'sum', 
                'CELL':'sum', 
                'AMINO_ACID':'sum', 
                'GENE_OR_GENE_PRODUCT':'sum', 
                'SIMPLE_CHEMICAL':'sum', 
                'ANATOMICAL_SYSTEM':'sum',
                'IMMATERIAL_ANATOMICAL_ENTITY':'sum', 
                'MULTI-TISSUE_STRUCTURE':'sum', 
                'DEVELOPING_ANATOMICAL_STRUCTURE':'sum',
                'ORGANISM_SUBDIVISION':'sum', 
                'CELLULAR_COMPONENT':'sum', 
                'PATHOLOGICAL_FORMATION':'sum', 
                'ORGANISM_SUBSTANCE':'sum'}
#for col in tqdm(column_remap.keys()):
#    df[col] = [i.split("~") if isinstance(i, str) else i for i in df[col].to_list()]
df.to_pickle("v6-7bySection.pkl",compression="gzip")

# %%
df.fillna("[]", inplace=True)
sentences = df.groupby(['paper_id','section'])['sentence'].apply(' '.join).reset_index()["sentence"].to_list()
print("Made sentences")
df = df.groupby(['paper_id','section']).agg(column_remap)
print("Grouped and aggregated.")
df["sentence"] = sentences
print("Assigned column")
df.to_pickle("v6-7bySection.pkl", compression="gzip")
# Out:
# Made sentences
# Grouped and aggregated.
# Assigned column

# %%
df = pd.read_pickle("v6-7bySection.pkl", compression="gzip")

# %%
sentence_id = [df.iloc[i]["paper_id"][0:5] + str(i) + df.iloc[i]["paper_id"][-5:] for i in df.index]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c9b31a967072> in <module>
# ----> 1 sentence_id = [df.iloc[i]["paper_id"][0:5] + str(i) + df.iloc[i]["paper_id"][-5:] for i in df.index]
#
# <ipython-input-6-c9b31a967072> in <listcomp>(.0)
# ----> 1 sentence_id = [df.iloc[i]["paper_id"][0:5] + str(i) + df.iloc[i]["paper_id"][-5:] for i in df.index]
#
# ~/anaconda3/envs/covid/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/envs/covid/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2138             self._validate_integer(key, axis)
#    2139
# -> 2140             return self._get_loc(key, axis=axis)
#    2141
#    2142     # raise_missing is included for compat with the parent class signature
#
# ~/anaconda3/envs/covid/lib/python3.7/site-packages/pandas/core/indexing.py in _get_loc(self, key, axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
# --> 628         return self.obj._ixs(key, axis=axis)
#     629
#     630     def _slice(self, obj, axis: int, kind=None):
#
# ~/anaconda3/envs/covid/lib/python3.7/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    2741                 index=self.columns,
#    2742                 name=self.index[i],
# -> 2743                 dtype=new_values.dtype,
#    2744             )
#    2745             result._set_is_copy(self, copy=copy)
#
# ~/anaconda3/envs/covid/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     213
#     214             if index is not None:
# --> 215                 index = ensure_index(index)
#     216
#     217             if data is None:
#
# ~/anaconda3/envs/covid/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5323     ensure_index_from_sequences
#    5324     """
# -> 5325     if isinstance(index_like, Index):
#    5326         if copy:
#    5327             index_like = index_like.copy()
#
# KeyboardInterrupt:

# %%
li1 = [i[:5] for i in df["paper_id"].to_list()]
li2 = [i for i in df.index]
li3 = [i[-5:] for i in df["paper_id"].to_list()]
sentence_id = [x + str(y) + z for x,y,z in zip(li1, li2, li3)]

# %%
x = []
for i in df.index:
    x.append(i[0][0:5] + i[1].replace(" ","").replace("'","").replace('"',"").replace("[]","None"))

# %%
df["section_id"] = x

# %%
df2 = df[0:5]

# %%
bulk_index(df, "cord19sections")

# %%
df
# Out:
#                                                                                                                                          lemma  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                            [feline, infectious, peritonitis, virus, (, fi...
#                                          antibodies                                          [monospecific, ,, polyclonal, antibody, origin...
#                                          cats with naturally occurring fip                   [twelve, cat, strongly, suspect, of, fip, by, ...
#                                          characterization of fipv positive cells             [the, obtain, cell, suspension, from, the, exu...
#                                          cultivation of fipv positive cells                  [the, isolate, cell, from, cat, 10, ,, 11, and...
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                        [there, be, many, record, about, crystal, ,, s...
#                                          recent progress                                     [the, last, five, year, have, see, a, new, cli...
#                                          tabref0                                             [major, structural, genomic, initiative, in, C...
#                                          the key development of protein crystallography ...  [structural, biology, be, a, discipline, base,...
#                                          title                                               [history, of, protein, crystallography, in, Ch...
#
#                                                                                                                                           UMLS  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                            [Family Felidae, Feline infectious peritonitis...
#                                          antibodies                                          [Entity Determiner - specific, Polyclonal anti...
#                                          cats with naturally occurring fip                   [Felis catus, Suspected diagnosis, Feline infe...
#                                          characterization of fipv positive cells             [Suspensions, Exudate, Body tissue, Pyogenic g...
#                                          cultivation of fipv positive cells                  [Isolated, Cells, Felis catus, Anthropological...
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                        [Quantity limited request - Records, Crystal P...
#                                          recent progress                                     [year, Crystallography, China, goal attainment...
#                                          tabref0                                                           [Major, Structural Genomics, China]
#                                          the key development of protein crystallography ...  [structural biology, discipline, structure, De...
#                                          title                                                                        [Crystallography, China]
#
#                                                                                                                                            GGP  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                                                           []
#                                          antibodies                                                                       [serotypes I and II]
#                                          cats with naturally occurring fip                                                                  []
#                                          characterization of fipv positive cells                                                            []
#                                          cultivation of fipv positive cells                                                                 []
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                             [insulin, ribosomal protein]
#                                          recent progress                                     [SARS coronavirus protein, nsp7-nsp8, nsp8, ns...
#                                          tabref0                                                                                            []
#                                          the key development of protein crystallography ...  [bovine insulin, insulin, insulin, insulin, in...
#                                          title                                                                                              []
#
#                                                                                                                                             SO  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                                                           []
#                                          antibodies                                                                                         []
#                                          cats with naturally occurring fip                                                                  []
#                                          characterization of fipv positive cells                                                            []
#                                          cultivation of fipv positive cells                                                                 []
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                                     [trichosanthin, DNA]
#                                          recent progress                                     [pro structure, pro crystal, genes, fragments,...
#                                          tabref0                                                                                            []
#                                          the key development of protein crystallography ...      [trichosanthin, trichosanthin, trichosanthin]
#                                          title                                                                                              []
#
#                                                                                                                                          TAXON  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                            [virus, cats, cats, viral, viral]
#                                          antibodies                                                               [cats, cat, Ab, viruses, Ab]
#                                          cats with naturally occurring fip                                                         [cats, cat]
#                                          characterization of fipv positive cells                                            [cat, viral, cats]
#                                          cultivation of fipv positive cells                                                      [cats, viral]
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                                                       []
#                                          recent progress                                     [human, virus proteins, coronavirus, mouse, vi...
#                                          tabref0                                                                                            []
#                                          the key development of protein crystallography ...                                                 []
#                                          title                                                                                              []
#
#                                                                                                                                          CHEBI  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                                                  [molecules]
#                                          antibodies                                                                                  [protein]
#                                          cats with naturally occurring fip                                                                  []
#                                          characterization of fipv positive cells                                                  [conjugates]
#                                          cultivation of fipv positive cells                                                                 []
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                          [molecular, protein, protein, protein, protein]
#                                          recent progress                                     [protein, protein, protein complex, proteins, ...
#                                          tabref0                                                                                            []
#                                          the key development of protein crystallography ...  [molecular, protein, protein, protein, protein...
#                                          title                                                                                       [protein]
#
#                                                                                                                                             GO  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                                                           []
#                                          antibodies                                          [antibodies, antibodies, antibodies, antibodie...
#                                          cats with naturally occurring fip                                                                  []
#                                          characterization of fipv positive cells                                         [nucleus, antibodies]
#                                          cultivation of fipv positive cells                                                                 []
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                [nuclear magnetic resonance spectroscopy]
#                                          recent progress                                     [membrane proteins, membrane, membrane protein...
#                                          tabref0                                                                                            []
#                                          the key development of protein crystallography ...                                                 []
#                                          title                                                                                              []
#
#                                                                                                                                             CL  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                            [cells, cells, cells, cells, cells, cells, cells]
#                                          antibodies                                                                                         []
#                                          cats with naturally occurring fip                                                                  []
#                                          characterization of fipv positive cells             [cell, cells, cells, granulocytes, macrophages...
#                                          cultivation of fipv positive cells                                                            [cells]
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                                                       []
#                                          recent progress                                                  [Cell, Cell, eukaryotic cells, cell]
#                                          tabref0                                                                                            []
#                                          the key development of protein crystallography ...                              [natural neurotoxins]
#                                          title                                                                                              []
#
#                                                                                                                         DNA  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                                        []
#                                          antibodies                                                                      []
#                                          cats with naturally occurring fip                                               []
#                                          characterization of fipv positive cells                                         []
#                                          cultivation of fipv positive cells                                              []
# ...                                                                                                                     ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                                    []
#                                          recent progress                                     [SARS, nsp8, letter 'q', TSC2]
#                                          tabref0                                                                         []
#                                          the key development of protein crystallography ...                    [Ruchang Bi]
#                                          title                                                                           []
#
#                                                                                                                                      CELL_TYPE  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                            [monocyte/macrophage lineage, FIPV positive ce...
#                                          antibodies                                                                                         []
#                                          cats with naturally occurring fip                                                                  []
#                                          characterization of fipv positive cells             [FIPV positive cells, granulocytes, macrophage...
#                                          cultivation of fipv positive cells                                                   [isolated cells]
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                                                       []
#                                          recent progress                                                                    [eukaryotic cells]
#                                          tabref0                                                                                            []
#                                          the key development of protein crystallography ...                                                 []
#                                          title                                                                                              []
#
#                                                                                              ...  \
# paper_id                                 section                                             ...
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                            ...
#                                          antibodies                                          ...
#                                          cats with naturally occurring fip                   ...
#                                          characterization of fipv positive cells             ...
#                                          cultivation of fipv positive cells                  ...
# ...                                                                                          ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                        ...
#                                          recent progress                                     ...
#                                          tabref0                                             ...
#                                          the key development of protein crystallography ...  ...
#                                          title                                               ...
#
#                                                                                             ANATOMICAL_SYSTEM  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                          []
#                                          antibodies                                                        []
#                                          cats with naturally occurring fip                                 []
#                                          characterization of fipv positive cells                           []
#                                          cultivation of fipv positive cells                                []
# ...                                                                                                       ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                      []
#                                          recent progress                                                   []
#                                          tabref0                                                           []
#                                          the key development of protein crystallography ...                []
#                                          title                                                             []
#
#                                                                                             IMMATERIAL_ANATOMICAL_ENTITY  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                                     []
#                                          antibodies                                                                   []
#                                          cats with naturally occurring fip                                            []
#                                          characterization of fipv positive cells                                      []
#                                          cultivation of fipv positive cells                                           []
# ...                                                                                                                  ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                                 []
#                                          recent progress                                                              []
#                                          tabref0                                                                      []
#                                          the key development of protein crystallography ...                           []
#                                          title                                                                        []
#
#                                                                                             MULTI-TISSUE_STRUCTURE  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                               []
#                                          antibodies                                                             []
#                                          cats with naturally occurring fip                                      []
#                                          characterization of fipv positive cells                                []
#                                          cultivation of fipv positive cells                                     []
# ...                                                                                                            ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                           []
#                                          recent progress                                                        []
#                                          tabref0                                                                []
#                                          the key development of protein crystallography ...                     []
#                                          title                                                                  []
#
#                                                                                             DEVELOPING_ANATOMICAL_STRUCTURE  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                                        []
#                                          antibodies                                                                      []
#                                          cats with naturally occurring fip                                               []
#                                          characterization of fipv positive cells                                         []
#                                          cultivation of fipv positive cells                                              []
# ...                                                                                                                     ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                                    []
#                                          recent progress                                                                 []
#                                          tabref0                                                                         []
#                                          the key development of protein crystallography ...                              []
#                                          title                                                                           []
#
#                                                                                             ORGANISM_SUBDIVISION  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                             []
#                                          antibodies                                                           []
#                                          cats with naturally occurring fip                                    []
#                                          characterization of fipv positive cells                              []
#                                          cultivation of fipv positive cells                                   []
# ...                                                                                                          ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                         []
#                                          recent progress                                                      []
#                                          tabref0                                                              []
#                                          the key development of protein crystallography ...                   []
#                                          title                                                                []
#
#                                                                                                                             CELLULAR_COMPONENT  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                                                    [surface]
#                                          antibodies                                                                                         []
#                                          cats with naturally occurring fip                                                                  []
#                                          characterization of fipv positive cells                                   [nucleus, surface, surface]
#                                          cultivation of fipv positive cells                                                          [surface]
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                                           [DNA, nuclear]
#                                          recent progress                                     [membrane, nsp7-nsp8, membrane, membrane, memb...
#                                          tabref0                                                                                            []
#                                          the key development of protein crystallography ...                        [macromolecules, ribosomal]
#                                          title                                                                                              []
#
#                                                                                             PATHOLOGICAL_FORMATION  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                               []
#                                          antibodies                                                             []
#                                          cats with naturally occurring fip                                      []
#                                          characterization of fipv positive cells                                []
#                                          cultivation of fipv positive cells                                     []
# ...                                                                                                            ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                           []
#                                          recent progress                                                        []
#                                          tabref0                                                                []
#                                          the key development of protein crystallography ...                     []
#                                          title                                                                  []
#
#                                                                                             ORGANISM_SUBSTANCE  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                           []
#                                          antibodies                                                         []
#                                          cats with naturally occurring fip                                  []
#                                          characterization of fipv positive cells                            []
#                                          cultivation of fipv positive cells                                 []
# ...                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                       []
#                                          recent progress                                                    []
#                                          tabref0                                                            []
#                                          the key development of protein crystallography ...                 []
#                                          title                                                              []
#
#                                                                                                                                       sentence  \
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                            Feline infectious peritonitis virus (FIPV) pos...
#                                          antibodies                                          Monospecific, polyclonal antibodies originatin...
#                                          cats with naturally occurring fip                   Twelve cats strongly suspected of FIP by clini...
#                                          characterization of fipv positive cells             The obtained cell suspensions from the exudate...
#                                          cultivation of fipv positive cells                  The isolated cells from cats 10, 11 and 12 wer...
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                        There are many records about crystals, such as...
#                                          recent progress                                     The last five years have seen a new climax in ...
#                                          tabref0                                               Major structural genomics initiatives in China.
#                                          the key development of protein crystallography ...  Structural biology is a discipline based on th...
#                                          title                                                     History of protein crystallography in China
#
#                                                                                                                                     section_id
# paper_id                                 section
# 0001418189999fea7f7cbe3e82703d71c85a6fe5 abstract                                                                                00014abstract
#                                          antibodies                                                                            00014antibodies
#                                          cats with naturally occurring fip                                  00014catswithnaturallyoccurringfip
#                                          characterization of fipv positive cells                      00014characterizationoffipvpositivecells
#                                          cultivation of fipv positive cells                                00014cultivationoffipvpositivecells
# ...                                                                                                                                        ...
# fffdca958d2869303da6e8e5e4b181e5de8f3854 introduction                                                                        fffdcintroduction
#                                          recent progress                                                                   fffdcrecentprogress
#                                          tabref0                                                                                  fffdctabref0
#                                          the key development of protein crystallography ...  fffdcthekeydevelopmentofproteincrystallography...
#                                          title                                                                                      fffdctitle
#
# [765651 rows x 33 columns]
